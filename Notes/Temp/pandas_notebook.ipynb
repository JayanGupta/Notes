# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
df = pd.read_csv('/content/movies.csv')

# %%
df.head(5)
# Out:
#            id                      name  year  rating certificate duration  \
# 0   tt0068646             The Godfather  1972     9.2           R  175 min
# 1   tt5113044  Minions: The Rise of Gru  2022     7.3          PG   87 min
# 2   tt7657566         Death on the Nile  2022     6.3       PG-13  127 min
# 3   tt8115900              The Bad Guys  2022     6.9          PG  100 min
# 4  tt10809742                 Collision  2022     3.8       TV-MA   99 min
#
#                           genre    votes gross_income  \
# 0                  Crime, Drama  1798749  134,966,411
# 1  Animation, Adventure, Comedy    1,220  134,966,411
# 2         Crime, Drama, Mystery  121,063  134,966,411
# 3  Animation, Adventure, Comedy   23,090  134,966,411
# 4        Crime, Drama, Thriller      656  134,966,411
#
#                     directors_id                            directors_name  \
# 0                      nm0000338                      Francis Ford Coppola
# ...

# %%
df.tail(3)
# Out:
#               id                                       name  year  rating  \
# 19805  tt0168950  Let It Come Down: The Life of Paul Bowles  1998     6.9
# 19806  tt0267563                                     Hybrid  2000     7.4
# 19807  tt0116481       Hands on a Hardbody: The Documentary  1997     7.6
#
#       certificate duration                       genre votes gross_income  \
# 19805   Not Rated   75 min      Documentary, Biography   125        9,188
# 19806   Not Rated   92 min      Documentary, Biography   146      159,403
# 19807          PG   98 min  Documentary, Comedy, Drama  2167      492,876
#
#                             directors_id                     directors_name  \
# 19805                          nm0047028                  Jennifer Baichwal
# 19806  /name/nm0566144/,/name/nm1084921/  Monteith McCollum,Milford Beeghly
# 19807                          nm0082835                       S.R. Bindler
#
#                                       stars_id  \
# ...

# %%
df.sample(3) # used for better analysis
# Out:
#               id                           name  year  rating certificate  \
# 16311  tt0293832                Hansel & Gretel  2002     4.4          PG
# 15294  tt1094666                     The Hammer  2010     6.9       PG-13
# 1944   tt0087932  The Pope of Greenwich Village  1984     6.6           R
#
#       duration                    genre votes gross_income directors_id  \
# 16311   89 min  Comedy, Family, Fantasy  1403      154,642    nm0876683
# 15294  108 min  Biography, Drama, Sport  1801       75,729    nm1464150
# 1944   121 min    Action, Comedy, Crime  8885    6,139,896    nm0742341
#
#             directors_name                                 stars_id  \
# 16311  Gary J. Tunnicliffe  nm0001655,nm0808559,nm0597410,nm0004785
# 15294          Oren Kaplan  nm2341751,nm0000855,nm0998074,nm2275302
# 1944      Stuart Rosenberg  nm0000616,nm0000620,nm0000435,nm0656183
#
#                                               stars_name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  object
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  object
#  8   gross_income    19808 non-null  object
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#                year        rating
# count  19808.000000  19808.000000
# mean    1995.546597      6.041973
# std       22.801725      1.206831
# min     1894.000000      1.100000
# 25%     1983.000000      5.300000
# 50%     2003.000000      6.200000
# 75%     2014.000000      6.900000
# max     2022.000000      9.700000

# %%
df.isnull().sum()
# Out:
# id                0
# name              0
# year              0
# rating            0
# certificate       0
# duration          0
# genre             0
# votes             0
# gross_income      0
# directors_id      0
# directors_name    0
# stars_id          0
# stars_name        0
# description       0
# dtype: int64

# %% [markdown]
# Q3. How do we clean the `duration` column? (e.g., `'175 min'` → `175`)

# %%
df['duration'] = df['duration'].str.replace('min',"")

df['duration'] = df['duration'].str.replace(',',"")

# %%
df["duration"] = df['duration'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  int64
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  object
#  8   gross_income    19808 non-null  object
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#                year        rating      duration
# count  19808.000000  19808.000000  19808.000000
# mean    1995.546597      6.041973    101.777968
# std       22.801725      1.206831     43.178721
# min     1894.000000      1.100000      1.000000
# 25%     1983.000000      5.300000     90.000000
# 50%     2003.000000      6.200000     98.000000
# 75%     2014.000000      6.900000    111.000000
# max     2022.000000      9.700000   5220.000000

# %% [markdown]
# Q4. How do we clean the `gross` column and `votes` column?

# %%
df["gross_income"] = df["gross_income"].str.replace(",","")

df["gross_income"] = df["gross_income"].str.replace('$',"")

df["gross_income"] = df["gross_income"].str.replace('M',"")

# %%
df["gross_income"] = df["gross_income"].astype(float)

# %%
df["votes"] = df["votes"].str.replace(",","")

df["votes"] = df["votes"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  int64
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  int64
#  8   gross_income    19808 non-null  float64
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 2.1+ MB

# %%
df.head()
# Out:
#            id                      name  year  rating certificate  duration  \
# 0   tt0068646             The Godfather  1972     9.2           R       175
# 1   tt5113044  Minions: The Rise of Gru  2022     7.3          PG        87
# 2   tt7657566         Death on the Nile  2022     6.3       PG-13       127
# 3   tt8115900              The Bad Guys  2022     6.9          PG       100
# 4  tt10809742                 Collision  2022     3.8       TV-MA        99
#
#                           genre    votes  gross_income  \
# 0                  Crime, Drama  1798749   134966411.0
# 1  Animation, Adventure, Comedy     1220   134966411.0
# 2         Crime, Drama, Mystery   121063   134966411.0
# 3  Animation, Adventure, Comedy    23090   134966411.0
# 4        Crime, Drama, Thriller      656   134966411.0
#
#                     directors_id                            directors_name  \
# 0                      nm0000338                      Francis Ford Coppola
# ...

# %% [markdown]
# Q5. How many missing values are in each column?

# %%
df.isnull().sum()
# Out:
# id                0
# name              0
# year              0
# rating            0
# certificate       0
# duration          0
# genre             0
# votes             0
# gross_income      0
# directors_id      0
# directors_name    0
# stars_id          0
# stars_name        0
# description       0
# dtype: int64

# %% [markdown]
# Q7. Find the "Hidden Gems" (High Rating, Low Votes)

# %%
df.describe()
# Out:
#                year        rating      duration         votes  gross_income
# count  19808.000000  19808.000000  19808.000000  1.980800e+04  1.980800e+04
# mean    1995.546597      6.041973    101.777968  3.694303e+04  1.682198e+07
# std       22.801725      1.206831     43.178721  1.129755e+05  4.642034e+07
# min     1894.000000      1.100000      1.000000  5.000000e+00  0.000000e+00
# 25%     1983.000000      5.300000     90.000000  1.058000e+03  1.196010e+05
# 50%     2003.000000      6.200000     98.000000  4.233000e+03  1.158192e+06
# 75%     2014.000000      6.900000    111.000000  2.045350e+04  1.243278e+07
# max     2022.000000      9.700000   5220.000000  2.574832e+06  9.366622e+08

# %%
df[ (df['rating'] > 6.9) & (df["votes"] < 1058) ]
# Out:
#                id                                               name  year  \
# 3423    tt4106286                                    Tiny Detectives  2014
# 3502    tt0042953                                          Shakedown  1950
# 3522    tt0070552                                         High Crime  1973
# 3594    tt0246879                                            Qurbani  1980
# 3980   tt13634096                                     The Bacon Hair  2020
# ...           ...                                                ...   ...
# 19799   tt1486548  Ahead of Time: The Extraordinary Journey of Ru...  2009
# 19800   tt0044917                             Amazing Monsieur Fabre  1951
# 19801   tt1334479                             Yoo-Hoo, Mrs. Goldberg  2009
# 19802   tt1518255                                          Raw Faith  2010
# 19806   tt0267563                                             Hybrid  2000
#
# ...

# %% [markdown]
# Q8. Find the "Overhyped" movies (Low Rating, High Gross)

# %%
df.describe()
# Out:
#                year        rating      duration         votes  gross_income
# count  19808.000000  19808.000000  19808.000000  1.980800e+04  1.980800e+04
# mean    1995.546597      6.041973    101.777968  3.694303e+04  1.682198e+07
# std       22.801725      1.206831     43.178721  1.129755e+05  4.642034e+07
# min     1894.000000      1.100000      1.000000  5.000000e+00  0.000000e+00
# 25%     1983.000000      5.300000     90.000000  1.058000e+03  1.196010e+05
# 50%     2003.000000      6.200000     98.000000  4.233000e+03  1.158192e+06
# 75%     2014.000000      6.900000    111.000000  2.045350e+04  1.243278e+07
# max     2022.000000      9.700000   5220.000000  2.574832e+06  9.366622e+08

# %%
import kagglehub


# Download latest version
path = kagglehub.dataset_download("ziya07/industrial-iot-fault-detection-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 32.5k/32.5k [00:00<00:00, 17.5MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/ziya07/industrial-iot-fault-detection-dataset/versions/1

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mlg-ulb/creditcardfraud")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'creditcardfraud' dataset.
# Path to dataset files: /kaggle/input/creditcardfraud

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nehalbirla/vehicle-dataset-from-cardekho")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 292k/292k [00:00<00:00, 73.0MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/nehalbirla/vehicle-dataset-from-cardekho/versions/4

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shyamnadhs/heart-disease-prediction-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 16.1k/16.1k [00:00<00:00, 18.2MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/shyamnadhs/heart-disease-prediction-dataset/versions/3

# %% [markdown]
# # Q9. What are the unique certificates in the dataset?

# %%
df["certificate"].unique()
# Out:
# array(['R', 'PG', 'PG-13', 'TV-MA', 'Not Rated', 'Approved', 'TV-14',
#        'NC-17', 'Unrated', 'G', 'Passed', 'GP', 'X', 'M/PG', 'M', 'TV-PG',
#        'TV-G', '12', 'TV-13', 'TV-Y7-FV', 'MA-17', 'AO', '18', 'R-15',
#        'R-12', 'R-18', 'PG-12', '6+', 'TV-Y7', 'TV-Y', 'MA-13'],
#       dtype=object)

# %%
df["certificate"].nunique()
# Out:
# 31

# %% [markdown]
# # Q10. How many movies were released each year?

# %%
df.head()
# Out:
#            id                      name  year  rating certificate  duration  \
# 0   tt0068646             The Godfather  1972     9.2           R       175
# 1   tt5113044  Minions: The Rise of Gru  2022     7.3          PG        87
# 2   tt7657566         Death on the Nile  2022     6.3       PG-13       127
# 3   tt8115900              The Bad Guys  2022     6.9          PG       100
# 4  tt10809742                 Collision  2022     3.8       TV-MA        99
#
#                           genre    votes  gross_income  \
# 0                  Crime, Drama  1798749   134966411.0
# 1  Animation, Adventure, Comedy     1220   134966411.0
# 2         Crime, Drama, Mystery   121063   134966411.0
# 3  Animation, Adventure, Comedy    23090   134966411.0
# 4        Crime, Drama, Thriller      656   134966411.0
#
#                     directors_id                            directors_name  \
# 0                      nm0000338                      Francis Ford Coppola
# ...

# %%
df.groupby('year')['id'].count().sort_index(ascending = False)
# Out:
# year
# 2022    174
# 2021    470
# 2020    467
# 2019    657
# 2018    736
#        ...
# 1913      3
# 1903      1
# 1902      2
# 1898      1
# 1894      1
# Name: id, Length: 114, dtype: int64

# %%
df['year'].value_counts().sort_index(ascending = False)
# Out:
# year
# 2022    174
# 2021    470
# 2020    467
# 2019    657
# 2018    736
#        ...
# 1913      3
# 1903      1
# 1902      2
# 1898      1
# 1894      1
# Name: count, Length: 114, dtype: int64

# %% [markdown]
# # Q11. Which are the top 5 most common genres?

# %%
x = df["genre"].str.split(",").explode()
x = x.str.strip()

# %%
x.value_counts().head(5)
# Out:
# genre
# Drama       9655
# Action      5290
# Crime       5244
# Comedy      4641
# Thriller    4231
# Name: count, dtype: int64

# %%
# Q12. Which directors have directed the most movies?

y = df["directors_name"].str.split(",").explode()

y = y.str.strip()

# %%
y.value_counts().head()
# Out:
# directors_name
# Clint Eastwood      38
# Alfred Hitchcock    38
# Henry Hathaway      31
# John Ford           31
# Raoul Walsh         31
# Name: count, dtype: int64

# %%
# Q13. Do longer movies get better ratings?

df[['duration',"rating"]].corr()
# Out:
#           duration    rating
# duration  1.000000  0.130112
# rating    0.130112  1.000000

# %%
# Q14. Which genre has the highest average rating?

g = df.assign(genre = df["genre"].str.split(", ")).explode('genre')

# %%
g.groupby("genre")["rating"].mean().sort_values(ascending = False).head()
# Out:
# genre
# Documentary    7.185514
# Reality-TV     7.100000
# Short          7.063351
# Biography      6.860367
# Film-Noir      6.821493
# Name: rating, dtype: float64

# %% [markdown]
# # Which genre makes the most money?

# %%
highest = df.assign(genre = df["genre"].str.split(", ")).explode("genre")

# %%
highest.groupby("genre")["gross_income"].mean().sort_values(ascending = False).head(5)
# Out:
# genre
# Animation    4.496143e+07
# Adventure    4.201662e+07
# Sci-Fi       3.358844e+07
# Fantasy      2.804439e+07
# Family       2.800047e+07
# Name: gross_income, dtype: float64

# %% [markdown]
# # Q16. Who is the highest-grossing director of all time (in this dataset)?

# %%
df.groupby("directors_name")["gross_income"].sum().sort_values(ascending = False).head()
# Out:
# directors_name
# Steven Spielberg           4.247700e+09
# Michael Bay                2.703051e+09
# Anthony Russo,Joe Russo    2.262877e+09
# J.J. Abrams                2.199407e+09
# Peter Jackson              2.156934e+09
# Name: gross_income, dtype: float64

# %% [markdown]
# # Q17. How does Certificate affect Gross Income?

# %%
df.groupby("certificate")["gross_income"].mean().sort_values(ascending = False).head()
# Out:
# certificate
# GP       6.221153e+07
# PG-13    4.571531e+07
# MA-17    3.806747e+07
# R-18     3.474929e+07
# PG       2.997915e+07
# Name: gross_income, dtype: float64

# %% [markdown]
# # Q18. What is the average duration of movies by Certificate?

# %%
df.groupby("certificate")["duration"].mean().sort_values(ascending = False).head(10)
# Out:
# certificate
# R-15         127.333333
# R-18         126.571429
# R-12         123.339623
# PG-12        117.540984
# 6+           114.000000
# M/PG         110.666667
# PG-13        106.786859
# M            105.793103
# Not Rated    104.813337
# GP           104.362963
# Name: duration, dtype: float64

# %% [markdown]
# # Q19. Are ratings improving over the years?

# %%
rpy = df.groupby("year")["rating"].mean().sort_index()

# %%
rpy[1990] # Example
# Out:
# np.float64(5.786363636363636)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (12,6))

plt.plot(rpy.index , rpy.values , color = "darkblue" , marker = "o" , linestyle = ":" , markersize = 5)

plt.xlabel("Year")
plt.ylabel("Average Rating")
plt.title("Are ratings improving over the years ? ")

plt.grid()
plt.show()
